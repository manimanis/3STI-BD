# %%
import pandas as pd
from random import randint
from datetime import datetime, date, timedelta

# %%
persons_names = [
    ('Dhieb', 'Hamed', 'M'),
    ('Karrout', 'Hedia', 'F'),
    ('Feki', 'Hichem', 'M'),
    ('Ben Salem', 'Souha', 'F'),
    ('Mejri', 'Sami', 'M'),
    ('Badii', 'Mayssa', 'F'),
    ('Ketari', 'Nabil', 'M'),
    ('Hamdi', 'Radhia', 'F'),
    ('Béji', 'Mejdi', 'M'),
    ('Khalil', 'Bochra', 'F')
]
patients = []
num_pat = 10
for nom, prenom, genre in persons_names:
    num_pat += 3
    patient = {
        'CodePat': f"P{num_pat}",
        'Nom': nom,
        'Prenom': prenom,
        'Genre': genre,
        'DateNaiss': str(date.today() - timedelta(days=randint(365*13, 365*80))),
        'Mutuelle': randint(0, 1)
    }
    patients.append(patient)
print(patients)
# Out:
# [{'CodePat': 'P13', 'Nom': 'Dhieb', 'Prenom': 'Hamed', 'Genre': 'M', 'DateNaiss': '1965-07-21', 'Mutuelle': 1}, {'CodePat': 'P16', 'Nom': 'Karrout', 'Prenom': 'Hedia', 'Genre': 'F', 'DateNaiss': '2004-02-09', 'Mutuelle': 1}, {'CodePat': 'P19', 'Nom': 'Feki', 'Prenom': 'Hichem', 'Genre': 'M', 'DateNaiss': '1950-07-23', 'Mutuelle': 0}, {'CodePat': 'P22', 'Nom': 'Ben Salem', 'Prenom': 'Souha', 'Genre': 'F', 'DateNaiss': '2007-06-29', 'Mutuelle': 1}, {'CodePat': 'P25', 'Nom': 'Mejri', 'Prenom': 'Sami', 'Genre': 'M', 'DateNaiss': '1985-06-16', 'Mutuelle': 0}, {'CodePat': 'P28', 'Nom': 'Badii', 'Prenom': 'Mayssa', 'Genre': 'F', 'DateNaiss': '1991-10-16', 'Mutuelle': 1}, {'CodePat': 'P31', 'Nom': 'Ketari', 'Prenom': 'Nabil', 'Genre': 'M', 'DateNaiss': '1984-04-11', 'Mutuelle': 1}, {'CodePat': 'P34', 'Nom': 'Hamdi', 'Prenom': 'Radhia', 'Genre': 'F', 'DateNaiss': '2004-09-04', 'Mutuelle': 0}, {'CodePat': 'P37', 'Nom': 'Béji', 'Prenom': 'Mejdi', 'Genre': 'M', 'DateNaiss': '1996-09-08', 'Mutuel
# ...

# %%
patients = [{'CodePat': 'P13', 'Nom': 'Dhieb', 'Prenom': 'Hamed', 'Genre': 'M', 'DateNaiss': '1965-07-21', 'Mutuelle': 1}, {'CodePat': 'P16', 'Nom': 'Karrout', 'Prenom': 'Hedia', 'Genre': 'F', 'DateNaiss': '2004-02-09', 'Mutuelle': 1}, {'CodePat': 'P19', 'Nom': 'Feki', 'Prenom': 'Hichem', 'Genre': 'M', 'DateNaiss': '1950-07-23', 'Mutuelle': 0}, {'CodePat': 'P22', 'Nom': 'Ben Salem', 'Prenom': 'Souha', 'Genre': 'F', 'DateNaiss': '2007-06-29', 'Mutuelle': 1}, {'CodePat': 'P25', 'Nom': 'Mejri', 'Prenom': 'Sami', 'Genre': 'M', 'DateNaiss': '1985-06-16', 'Mutuelle': 0}, {'CodePat': 'P28', 'Nom': 'Badii', 'Prenom': 'Mayssa', 'Genre': 'F', 'DateNaiss': '1991-10-16', 'Mutuelle': 1}, {'CodePat': 'P31', 'Nom': 'Ketari', 'Prenom': 'Nabil', 'Genre': 'M', 'DateNaiss': '1984-04-11', 'Mutuelle': 1}, {'CodePat': 'P34', 'Nom': 'Hamdi', 'Prenom': 'Radhia', 'Genre': 'F', 'DateNaiss': '2004-09-04', 'Mutuelle': 0}, {'CodePat': 'P37', 'Nom': 'Béji', 'Prenom': 'Mejdi', 'Genre': 'M', 'DateNaiss': '1996-09-08', 'Mutuelle': 1}, {'CodePat': 'P40', 'Nom': 'Khalil', 'Prenom': 'Bochra', 'Genre': 'F', 'DateNaiss': '1956-03-21', 'Mutuelle': 1}]

# %%
services = [
    {'NumServ': 10, 'LibServ': 'Urgences'},
    {'NumServ': 20, 'LibServ': 'Cardiologie'},
    {'NumServ': 30, 'LibServ': 'Chirurgie'},
    {'NumServ': 40, 'LibServ': 'Radiologie'},
    {'NumServ': 50, 'LibServ': 'Laboratoire'}
]

# %%
hospitalisation = []
for patient in patients:
    dte = date(2021, 1, 1) + timedelta(days=randint(0, 200))
    service = randint(1, 2)
    hosp = {
        'NumServ': services[0]['NumServ'],
        'CodePat': patient['CodePat'],
        'DateEntree': str(dte),
        'DateSortie': str(dte),
        'Frais': randint(20, 1000)/1.0
    }
    hospitalisation.append(hosp)
    if randint(0, 99) >= 40:
        nbt = randint(1, 6)
        dte = dte + timedelta(days=1)
        for i in range(nbt):
            days = randint(0, 10)
            dts = dte + timedelta(days=days)
            hosp = {
                'NumServ': services[service]['NumServ'],
                'CodePat': patient['CodePat'],
                'DateEntree': str(dte),
                'DateSortie': str(dts),
                'Frais': (days+1)*(40 + randint(0, 90)*5.0)
            }
            hospitalisation.append(hosp)
            for i in range(days):
                choix = randint(0, 3)
                hosp = {
                    'NumServ': '',
                    'CodePat': patient['CodePat'],
                    'DateEntree': str(dte+timedelta(days=i)),
                    'DateSortie': str(dte+timedelta(days=i)),
                    'Frais': 0.0
                }
                if (choix and 1) == 1:
                    hosp = hosp.copy()
                    hosp['NumServ'] = 40
                    hosp['Frais'] = 60.0
                    hospitalisation.append(hosp)
                if (choix and 2) == 2:
                    hosp = hosp.copy()
                    hosp['NumServ'] = 50
                    hosp['Frais'] = 60.0
                    hospitalisation.append(hosp)
            dte = dts + timedelta(days=randint(0, 90))
print(len(hospitalisation))
print(hospitalisation)
# Out:
# 156
# ...

# %%
hospitalisation = [{'NumServ': 10, 'CodePat': 'P13', 'DateEntree': '2021-06-28', 'DateSortie': '2021-06-28', 'Frais': 241.0}, {'NumServ': 30, 'CodePat': 'P13', 'DateEntree': '2021-06-29', 'DateSortie': '2021-06-30', 'Frais': 350.0}, {'NumServ': 40, 'CodePat': 'P13', 'DateEntree': '2021-06-29', 'DateSortie': '2021-06-29', 'Frais': 60.0}, {'NumServ': 50, 'CodePat': 'P13', 'DateEntree': '2021
 'Frais': 60.0}, {'NumServ': 50, 'CodePat': 'P40', 'DateEntree': '2021-12-07', 'DateSortie': '2021-12-07', 'Frais': 60.0}, {'NumServ': 40, 'CodePat': 'P40', 'DateEntree': '2021-12-08', 'DateSortie': '2021-12-08', 'Frais': 60.0}, {'NumServ': 50, 'CodePat': 'P40', 'DateEntree': '2021-12-08', 'DateSortie': '2021-12-08', 'Frais': 60.0}]

# %%
print("INSERT INTO service (" + 
      ", ".join(services[0].keys()) + 
      ")\nVALUES (" + 
      "),\n\t(".join(','.join("'" + str(val) + "'" for val in service.values()) for service in services) + ");")
# Out:
# INSERT INTO service (NumServ, LibServ)
# VALUES ('10','Urgences'),
# 	('20','Cardiologie'),
# 	('30','Chirurgie'),
# 	('40','Radiologie'),
# 	('50','Laboratoire');

# %%
print("INSERT INTO patient (" + 
      ", ".join(patients[0].keys()) + 
      ")\nVALUES (" + 
      "),\n\t(".join(','.join("'" + str(val) + "'" for val in item.values()) for item in patients) + ");")
# Out:
# INSERT INTO patient (CodePat, Nom, Prenom, Genre, DateNaiss, Mutuelle)
# VALUES ('P13','Dhieb','Hamed','M','1965-07-21','1'),
# 	('P16','Karrout','Hedia','F','2004-02-09','1'),
# 	('P19','Feki','Hichem','M','1950-07-23','0'),
# 	('P22','Ben Salem','Souha','F','2007-06-29','1'),
# 	('P25','Mejri','Sami','M','1985-06-16','0'),
# 	('P28','Badii','Mayssa','F','1991-10-16','1'),
# 	('P31','Ketari','Nabil','M','1984-04-11','1'),
# 	('P34','Hamdi','Radhia','F','2004-09-04','0'),
# 	('P37','Béji','Mejdi','M','1996-09-08','1'),
# 	('P40','Khalil','Bochra','F','1956-03-21','1');

# %%
print("INSERT INTO hospitalisation (" + 
      ", ".join(hospitalisation[0].keys()) + 
      ")\nVALUES (" + 
      "),\n\t(".join(','.join("'" + str(val) + "'" for val in item.values()) for item in hospitalisation) + ");")
# Out:
# INSERT INTO hospitalisation (NumServ, CodePat, DateEntree, DateSortie, Frais)
# VALUES ('10','P13','2021-06-28','2021-06-28','241.0'),
# 	('30','P13','2021-06-29','2021-06-30','350.0'),
# 	('40','P13','2021-06-29','2021-06-29','60.0'),
# 	('50','P13','2021-06-29','2021-06-29','60.0'),
# 	('30','P13','2021-08-21','2021-08-28','680.0'),
# 	('40','P13','2021-08-21','2021-08-21','60.0'),
# 	('50','P13','2021-08-21','2021-08-21','60.0'),
# 	('40','P13','2021-08-23','2021-08-23','60.0'),
# 	('50','P13','2021-08-23','2021-08-23','60.0'),
# 	('40','P13','2021-08-24','2021-08-24','60.0'),
# 	('50','P13','2021-08-24','2021-08-24','60.0'),
# 	('40','P13','2021-08-25','2021-08-25','60.0'),
# 	('50','P13','2021-08-25','2021-08-25','60.0'),
# 	('40','P13','2021-08-27','2021-08-27','60.0'),
# 	('50','P13','2021-08-27','2021-08-27','60.0'),
# 	('30','P13','2021-08-29','2021-09-08','4290.0'),
# 	('40','P13','2021-08-29','2021-08-29','60.0'),
# 	('50','P13','2021-08-29','2021-08-29','60.0'),
# ...
